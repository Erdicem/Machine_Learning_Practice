# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
columns = ["age","sex","cp","restbp","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal","num"]

# %%
df = pd.read_csv('cleveland-0_vs_4.dat', sep=",", names=columns)
df.head(25)
# Out:
#                                age        sex   cp    restbp   chol  fbs  \
# 0       @relation cleveland-0_vs_4        NaN  NaN       NaN    NaN  NaN
# 1        @attribute age real [29.0      77.0]  NaN       NaN    NaN  NaN
# 2         @attribute sex real [0.0       1.0]  NaN       NaN    NaN  NaN
# 3          @attribute cp real [1.0       4.0]  NaN       NaN    NaN  NaN
# 4   @attribute trestbps real [94.0     180.0]  NaN       NaN    NaN  NaN
# 5      @attribute chol real [126.0     564.0]  NaN       NaN    NaN  NaN
# 6         @attribute fbs real [0.0       1.0]  NaN       NaN    NaN  NaN
# 7     @attribute restecg real [0.0       2.0]  NaN       NaN    NaN  NaN
# 8    @attribute thalach real [96.0     202.0]  NaN       NaN    NaN  NaN
# 9       @attribute exang real [0.0       1.0]  NaN       NaN    NaN  NaN
# 10    @attribute oldpeak real [0.0       4.4]  NaN       NaN    NaN  NaN
# 11      @attribute slope real [1.0       3.0]  NaN       NaN    NaN  NaN
# ...

# %%
df= df.dropna()

# %%
df.head(25)
# Out:
#      age  sex   cp restbp   chol  fbs restecg thalach exang oldpeak slope  \
# 18  63.0  1.0  1.0  145.0  233.0  1.0     2.0   150.0   0.0     2.3   3.0
# 19  37.0  1.0  3.0  130.0  250.0  0.0     0.0   187.0   0.0     3.5   3.0
# 20  41.0  0.0  2.0  130.0  204.0  0.0     2.0   172.0   0.0     1.4   1.0
# 21  56.0  1.0  2.0  120.0  236.0  0.0     0.0   178.0   0.0     0.8   1.0
# 22  57.0  0.0  4.0  120.0  354.0  0.0     0.0   163.0   1.0     0.6   1.0
# 23  57.0  1.0  4.0  140.0  192.0  0.0     0.0   148.0   0.0     0.4   2.0
# 24  56.0  0.0  2.0  140.0  294.0  0.0     2.0   153.0   0.0     1.3   2.0
# 25  44.0  1.0  2.0  120.0  263.0  0.0     0.0   173.0   0.0     0.0   1.0
# 26  52.0  1.0  3.0  172.0  199.0  1.0     0.0   162.0   0.0     0.5   1.0
# 27  54.0  1.0  4.0  140.0  239.0  0.0     0.0   160.0   0.0     1.2   1.0
# 28  48.0  0.0  3.0  130.0  275.0  0.0     0.0   139.0   0.0     0.2   1.0
# 29  49.0  1.0  2.0  130.0  266.0  0.0     0.0   171.0   0.0     0.6   1.0
# ...

# %%
df['num'] = pd.get_dummies(df['num'])

# %%
df
# Out:
#       age  sex   cp restbp   chol  fbs restecg thalach exang oldpeak slope  \
# 18   63.0  1.0  1.0  145.0  233.0  1.0     2.0   150.0   0.0     2.3   3.0
# 19   37.0  1.0  3.0  130.0  250.0  0.0     0.0   187.0   0.0     3.5   3.0
# 20   41.0  0.0  2.0  130.0  204.0  0.0     2.0   172.0   0.0     1.4   1.0
# 21   56.0  1.0  2.0  120.0  236.0  0.0     0.0   178.0   0.0     0.8   1.0
# 22   57.0  0.0  4.0  120.0  354.0  0.0     0.0   163.0   1.0     0.6   1.0
# ..    ...  ...  ...    ...    ...  ...     ...     ...   ...     ...   ...
# 190  64.0  1.0  4.0  145.0  212.0  0.0     2.0   132.0   0.0     2.0   2.0
# 191  38.0  1.0  1.0  120.0  231.0  0.0     0.0   182.0   1.0     3.8   2.0
# 192  61.0  1.0  4.0  138.0  166.0  0.0     2.0   125.0   1.0     3.6   2.0
# 193  58.0  1.0  4.0  114.0  318.0  0.0     1.0   140.0   0.0     4.4   3.0
# 194  70.0  1.0  4.0  145.0  174.0  0.0     0.0   125.0   1.0     2.6   3.0
#
#       ca thal  num
# 18   0.0  6.0    1
# 19   0.0  3.0    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 18 to 194
# Data columns (total 14 columns):
# age        173 non-null float64
# sex        173 non-null float64
# cp         173 non-null float64
# restbp     173 non-null float64
# chol       173 non-null float64
# fbs        173 non-null float64
# restecg    173 non-null float64
# thalach    173 non-null float64
# exang      173 non-null float64
# oldpeak    173 non-null float64
# slope      173 non-null float64
# ca         173 non-null float64
# thal       173 non-null float64
# num        173 non-null uint8
# dtypes: float64(13), uint8(1)
# memory usage: 19.1 KB

# %%
df.isnull().sum()*100 / df.shape[0]
# Out:
# age        0.0
# sex        0.0
# cp         0.0
# restbp     0.0
# chol       0.0
# fbs        0.0
# restecg    0.0
# thalach    0.0
# exang      0.0
# oldpeak    0.0
# slope      0.0
# ca         0.0
# thal       0.0
# num        0.0
# dtype: float64

# %%
df['ca'].unique()
# Out:
# array(['0.0', '2.0', '1.0', '3.0', '<null>'], dtype=object)

# %%
df['ca'].value_counts()
# Out:
# 0.0       133
# 1.0        24
# 2.0         9
# 3.0         8
# <null>      3
# Name: ca, dtype: int64

# %%
df['ca'].replace('<null>',np.nan, inplace=True)

# %%
df['ca'].unique()
# Out:
# array(['0.0', '2.0', '1.0', '3.0', nan], dtype=object)

# %%
df['thal'].unique()
# Out:
# array(['6.0', '3.0', '7.0', '<null>'], dtype=object)

# %%
df['thal'].value_counts()
# Out:
# 3.0       131
# 7.0        37
# 6.0         8
# <null>      1
# Name: thal, dtype: int64

# %%
df['thal'].replace('<null>', np.nan, inplace= True)

# %%
df['thal'].value_counts()
# Out:
# 3.0    131
# 7.0     37
# 6.0      8
# Name: thal, dtype: int64

# %%
df= df.dropna()

# %%
import warnings
warnings.filterwarnings('ignore')
df['thal'] = df['thal'].astype('float')
df['ca'] = df['ca'].astype('float')

# %%
import seaborn as sns 
sns.pairplot(df , kind="reg")

# %%
df.head()
# Out:
#      age  sex   cp  restbp   chol  fbs  restecg  thalach  exang  oldpeak  \
# 18  63.0  1.0  1.0   145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 19  37.0  1.0  3.0   130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 20  41.0  0.0  2.0   130.0  204.0  0.0      2.0    172.0    0.0      1.4
# 21  56.0  1.0  2.0   120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 22  57.0  0.0  4.0   120.0  354.0  0.0      0.0    163.0    1.0      0.6
#
#     slope   ca  thal  num
# 18    3.0  0.0   6.0    1
# 19    3.0  0.0   3.0    1
# 20    1.0  0.0   3.0    1
# 21    1.0  0.0   3.0    1
# 22    1.0  0.0   3.0    1

# %%
df['num'].value_counts()
# Out:
# 1    160
# 0     13
# Name: num, dtype: int64

# %%
sns.countplot(df['num'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
def model_olustur (X,y):
    X_train, X_test , y_train, y_test = train_test_split(X,y, test_size=0.2 , random_state = 111 , stratify= y)
    logreg_model = LogisticRegression()
    logreg_model.fit(X_train , y_train)
    
    tahmin_train = logreg_model.predict(X_train)
    tahmin_test = logreg_model.predict(X_test)
    hata_matrix_train = confusion_matrix(y_train , tahmin_train)
    hata_matrix_test = confusion_matrix(y_test , tahmin_test)
    
    print("Accuracy:", logreg_model.score(X_test, y_test))
    print("Eğitim veri kümesi")
    print(classification_report(y_train , tahmin_train))
    print("Test Kümesi")
    print(classification_report(y_test, tahmin_test))
    return None

# %%
X = df.drop(['num'], axis=1)
y = df['num']
model_olustur(X,y)
# Out:
# Accuracy: 0.9428571428571428
# Eğitim veri kümesi
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        10
#            1       0.98      0.99      0.98       128
#
#     accuracy                           0.97       138
#    macro avg       0.93      0.85      0.88       138
# weighted avg       0.97      0.97      0.97       138
#
# Test Kümesi
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67         3
#            1       0.97      0.97      0.97        32
#
#     accuracy                           0.94        35
#    macro avg       0.82      0.82      0.82        35
# weighted avg       0.94      0.94      0.94        35

# %%
from sklearn.utils import resample

# %%
negatif = df[df['num']==0]
pozitif = df[df['num']==1]

negatif_arttırma = resample(negatif, replace=True , n_samples = len(pozitif), random_state=111)

negatif_arttırma_df = pd.concat([pozitif , negatif_artırılmış])
negatif_arttırma_df.num.value_counts()
# Out:
# 1    160
# 0    160
# Name: num, dtype: int64

# %%
X= negatif_arttırma_df.drop('num', axis=1)
y= negatif_arttırma_df['num']
model_olustur(X,y)
# Out:
# Accuracy: 0.96875
# Eğitim veri kümesi
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       128
#            1       1.00      0.95      0.98       128
#
#     accuracy                           0.98       256
#    macro avg       0.98      0.98      0.98       256
# weighted avg       0.98      0.98      0.98       256
#
# Test Kümesi
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        32
#            1       1.00      0.94      0.97        32
#
#     accuracy                           0.97        64
#    macro avg       0.97      0.97      0.97        64
# weighted avg       0.97      0.97      0.97        64

# %%
negatif = df[df['num']==0]
pozitif = df[df['num']==1]

pozitif_arttırma = resample(pozitif, replace=True , n_samples = len(negatif), random_state=111)

pozitif_arttırma_df = pd.concat([negatif , pozitif_arttırma])
pozitif_arttırma_df.num.value_counts()
# Out:
# 1    13
# 0    13
# Name: num, dtype: int64

# %%
X= pozitif_arttırma_df.drop('num', axis=1)
y= pozitif_arttırma_df['num']
model_olustur(X,y)
# Out:
# Accuracy: 1.0
# Eğitim veri kümesi
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        10
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20
#
# Test Kümesi
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
X= df.drop('num', axis=1)
y= df['num']

sm= SMOTE(random_state=27)
X_smote , y_smote = sm.fit_sample(X,y)

# %%
model_olustur(X_smote, y_smote)
# Out:
# Accuracy: 0.953125
# Eğitim veri kümesi
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       128
#            1       1.00      0.96      0.98       128
#
#     accuracy                           0.98       256
#    macro avg       0.98      0.98      0.98       256
# weighted avg       0.98      0.98      0.98       256
#
# Test Kümesi
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.96        32
#            1       1.00      0.91      0.95        32
#
#     accuracy                           0.95        64
#    macro avg       0.96      0.95      0.95        64
# weighted avg       0.96      0.95      0.95        64

# %% [markdown]
# # ADASYN

# %%
from imblearn.over_sampling import ADASYN

# %%
y= df['num']
X= df.drop('num', axis=1)

ad= ADASYN()
X_adasyn, y_adasyn = ad.fit_sample(X,y)

# %%
model_olustur(X_adasyn, y_adasyn)
# Out:
# Accuracy: 0.984375
# Eğitim veri kümesi
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       127
#            1       1.00      0.96      0.98       128
#
#     accuracy                           0.98       255
#    macro avg       0.98      0.98      0.98       255
# weighted avg       0.98      0.98      0.98       255
#
# Test Kümesi
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        32
#            1       1.00      0.97      0.98        32
#
#     accuracy                           0.98        64
#    macro avg       0.98      0.98      0.98        64
# weighted avg       0.98      0.98      0.98        64
